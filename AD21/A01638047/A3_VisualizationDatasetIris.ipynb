# %% [markdown]
# Natalia Velasco García A01638047
# # Visualizing Data in Python
# ## Importing libraries

# %%
# Import the packages that we will be using
import pandas as pd                 # For data handling
import seaborn as sns               # For advanced plotting
import matplotlib.pyplot as plt     # For showing plots

# %% [markdown]
# ## Importing data

# %%
# url string that hosts our .csv file
url = "datasets/iris/iris.csv"

# Read the .csv file and store it as a pandas Data Frame
df = pd.read_csv(url, names=["SepalLength", "SepalWidth", "PetalLength", "PetalWidth", "Class"])

# %% [markdown]
# ## Exploring the content of the data set

# %%
#df
df.shape
df.head()
#df.columns
#df.describe()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth        Class
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# # Frequency tables

# %%
# Number of times that each distinct value of a variable occurs in a data set
df.Class.value_counts()
# Out:
# Iris-virginica     50
# Iris-setosa        50
# Iris-versicolor    50
# Name: Class, dtype: int64

# %%
# Proportion of each distinct value of a variable occurs in a data set
x = df.Class.value_counts()
x / x.sum()
# Out:
# Iris-virginica     0.333333
# Iris-setosa        0.333333
# Iris-versicolor    0.333333
# Name: Class, dtype: float64

# %%
# Total number of observations in tips
print(df.shape)

# Total number of null observations in tips
#print(df.isnull(df.SepalLength).sum())

# Total number of counts (excluding missing values) in tips
print(df.Class.value_counts().sum())
# Out:
# (150, 5)
# 150

# %% [markdown]
# # Histogram

# %%
# Plot histogram of the Sepal Length
dfhist = sns.distplot(df["SepalLength"], kde = False)#.set_title("Histogram of Sepal Length")
dfhist.set_ylabel("Frequency")
dfhist.set_title("Histogram of Sepal Length")
plt.show()

# %%
# Plot distribution of the tips only
dfhist = sns.distplot(df["SepalLength"], kde = True)#.set_title("Distribution of the Sepal Length")
dfhist.set_ylabel("PDF")
dfhist.set_xlabel("Tip")
dfhist.set_title("Distribution of the Sepal Length")

plt.show()
# Out:
# C:\Users\natal\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Plot histogram of both the Sepal Length and the SepalWidth
sns.distplot(df["SepalLength"], kde = False)
dfhist = sns.distplot(df["SepalWidth"], kde = False)#.set_title("Histogram of both Age and Wingspan")
dfhist.set_ylabel("Frequency")
dfhist.set_title("Histogram of both Sepal Length and the SepalWidth")

plt.show()
# Out:
# C:\Users\natal\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Histograms plotted by groups

# %%
# Create histograms of the "SepalLength" grouped by "Class"
g = sns.FacetGrid(df, row = "Class")
g = g.map(plt.hist, "SepalLength")

plt.show()

# %% [markdown]
# # Boxplots

# %%
# Create the boxplot of the Sepal Length
sns.boxplot(df["SepalLength"]).set_title("Box plot of the Sepal Length")
plt.show()
# Out:
# C:\Users\natal\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Create the boxplot of the "tips" amounts
sns.boxplot(df["SepalWidth"]).set_title("Box plot of the Sepal Width")
plt.show()
# Out:
# C:\Users\natal\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Create the boxplots of the "SepalLength" and of the "SepalWidth" amounts
sns.boxplot(df["SepalLength"])
sns.boxplot(df["SepalWidth"]).set_title("Box plot of the Total Sepal Length and Sepal Width")
plt.show()

# NOTE: this is not convenient
# Out:
# C:\Users\natal\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\natal\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Create the boxplots of the "SepalLength" and of the "SepalWidth" amounts
BillAndTip = df.loc[:, ["SepalLength", "SepalWidth"]]

x2bp = sns.boxplot(data=BillAndTip, orient="h")
x2bp.set_xlabel("cm")
x2bp.set_title("Box plot of the Sepal Length and Sepal Width")

plt.show()

# %% [markdown]
# # Boxplots plotted by groups

# %%
# Create side-by-side boxplots of the "SepalLength" grouped by "Class"
sns.boxplot(x = df["SepalLength"], y = df["Class"])
plt.show()

# %% [markdown]
# # Histograms and boxplots plotted by groups

# %%
# Create a boxplot and histogram of the "tips" grouped by "Class"
sns.boxplot(x = df["SepalLength"], y = df["Class"])

g = sns.FacetGrid(df, row = "Class")
g = g.map(plt.hist, "SepalLength")

plt.show()

# %% [markdown]
# # Activity: work with the iris dataset
#
# Repeat this tutorial with the iris data set and respond to the following inquiries
#
# 1. Plot the histograms for each of the four quantitative variables

# %%
sns.distplot(df["SepalLength"], kde = False).set_title("Histogram of Sepal Length")
plt.show()
sns.distplot(df["SepalWidth"], kde = False).set_title("Histogram of Sepal Width")
plt.show()
sns.distplot(df["PetalLength"], kde = False).set_title("Histogram of Petal Length")
plt.show()
sns.distplot(df["PetalWidth"], kde = False).set_title("Histogram of Petal Width")
plt.show()

# %% [markdown]
# 2. Plot the histograms for each of the quantitative variables

# %%
sns.distplot(df["SepalLength"], kde = False).set_title("Histogram of Sepal Length")
sns.distplot(df["SepalWidth"], kde = False).set_title("Histogram of Sepal Width")
sns.distplot(df["PetalLength"], kde = False).set_title("Histogram of Petal Length")
sns.distplot(df["PetalWidth"], kde = False).set_title("Histogram of Petal Width")
plt.show()

# %% [markdown]
# 3. Plot the boxplots for each of the quantitative variables

# %%
SepalPetal = df.loc[:, ["SepalLength", "SepalWidth", "PetalLength", "PetalWidth"]]

x2bp = sns.boxplot(data=SepalPetal, orient="h")
x2bp.set_xlabel("CM")
x2bp.set_title("Box plot of the SepalLength, SepalWidth, PetalLength and PetalWidth")



plt.show()

# %% [markdown]
# 4. Plot the boxplots of the petal width grouped by type of flower

# %%
sns.boxplot(x = df["PetalWidth"], y = df["Class"])
plt.show()

# %% [markdown]
# 5. Plot the boxplots of the setal length grouped by type of flower

# %%
sns.boxplot(x = df["SepalLength"], y = df["Class"])
plt.show()

# %% [markdown]
# 6. Provide a description (explaination from your observations) of each of the quantitative variables
#
# Observé las diferencias de cada tipo de flor de acuerdo a su tamaño. Iris-setosa es la más pequeña (sépalo y pétalo) seguida de Iris-versicolor y por último Iris-virginica. Además el sépalo suele ser más largo y ancho que los pétalos .
