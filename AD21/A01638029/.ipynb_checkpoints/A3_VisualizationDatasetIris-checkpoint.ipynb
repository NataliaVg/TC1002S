# %% [markdown]
# # A2_DataManagmentIris
# Luis Humberto Sánchez Vaca A01638029

# %% [markdown]
# # Importing libraries

# %%
# Import the packages that we will be using
import pandas as pd                 # For data handling
import seaborn as sns               # For advanced plotting
import matplotlib.pyplot as plt     # For showing plots

# %% [markdown]
# # Importing data

# %%
# url string that hosts our .csv file
url = "datasets/iris/iris.csv"

# Read the .csv file and store it as a pandas Data Frame
df = pd.read_csv(url, names=['SepalLength','SepalWidth','PetalLength','PetalWidth','Class'])

# %% [markdown]
# # Exploring the content of the data set
#
# Get a general 'feel' of the data

# %%
#df
df.shape
df.head()
#df.columns
#df.describe()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth        Class
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# # Frequency tables
#
# The `value_counts()` method can be used to determine the number of times that each distinct value of a variable occurs in a data set.  In statistical terms, this is the "frequency distribution" of the variable. The `value_counts()` method produces a table with two columns.  The first column contains all distinct observed values for the variable.  The second column contains the number of times each of these values occurs.  Note that the table returned by `value_counts()` is actually a **Pandas** data frame, so can be further processed using any Pandas methods for working with data frames.

# %%
# Number of times that each distinct value of a variable occurs in a data set
df.Class.value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Class, dtype: int64

# %%
# Proportion of each distinct value of a variable occurs in a data set
x = df.Class.value_counts()
x / x.sum()
# Out:
# Iris-setosa        0.333333
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# Name: Class, dtype: float64

# %% [markdown]
# # Histogram
#
# It is often good to get a feel for the shape of the distribution of the data.

# %%
# Plot histogram of the petal width only
dfhist = sns.distplot(df["PetalWidth"], kde = False)
dfhist.set_ylabel("Frequency")
dfhist.set_title("Histogram of Petal width")
plt.show()
# Out:
# C:\Users\luisa\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Plot histogram of both the PetalLength and PetalWidth 
dfhist = sns.distplot(df["PetalLength"], kde = False)
dfhist = sns.distplot(df["PetalWidth"], kde = False)
dfhist.set_ylabel("Frequency")
dfhist.set_title("Histogram of both Petal length and width")
plt.show()

# %% [markdown]
# # Histograms plotted by groups
#
# While looking at a single variable is interesting, it is often useful to see how a variable changes in response to another. Thus, we can create a histograms of one quantitative variable grouped by another categorical variables.

# %%
# Create histograms of the "SepalLength" grouped by "Class"
g = sns.FacetGrid(df, row = "Class")
g = g.map(plt.hist, "SepalLength")

plt.show()

# %% [markdown]
# # Boxplots
#
# Boxplots do not show the shape of the distribution, but they can give us a better idea about the center and spread of the distribution as well as any potential outliers that may exist. Boxplots and Histograms often complement each other and help an analyst get more information about the data

# %%
# Create the boxplot of the "SepalWidth"
sns.boxplot(df["SepalWidth"]).set_title("Box plot of the SepalWidth")
plt.show()
# Out:
# C:\Users\luisa\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Create the boxplots of the "SepalWidth" and of the "SepalLength"
sns.boxplot(df["SepalWidth"])
sns.boxplot(df["SepalLength"]).set_title("Box plot of SepalWidth and SepalLength")
plt.show()

# NOTE: this is not convenient
# Out:
# C:\Users\luisa\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\luisa\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Create the boxplots of the "SepalWidth" and of the "SepalLength"
WidthAndLength = df.loc[:, ["SepalWidth", "SepalLength"]]

x2bp = sns.boxplot(data=WidthAndLength, orient="h")
x2bp.set_xlabel("Cm")
x2bp.set_title("Box plot of the SepalWidth and SepalLength")

plt.show()

# %% [markdown]
# # Boxplots plotted by groups
#
# While looking at a single variable is interesting, it is often useful to see how a variable changes in response to another. Thus, we can create a side-by-side boxplots of one quantitative variable grouped by another categorical variables.

# %%
# Create side-by-side boxplots of the "PetalWidth" grouped by "Class"
sns.boxplot(x = df["PetalWidth"], y = df["Class"])
plt.show()

# %% [markdown]
# # Histograms and boxplots plotted by groups
#
# We cal also create both boxplots and histograms of one quantitative variable grouped by another categorical variables

# %%
# Create a boxplot and histogram of the "PetalLength" grouped by "Class"
sns.boxplot(x = df["PetalLength"], y = df["Class"])

g = sns.FacetGrid(df, row = "Class")
g = g.map(plt.hist, "PetalLength")

plt.show()

# %% [markdown]
# # Activity: work with the iris dataset
#
# Repeat this tutorial with the iris data set and respond to the following inquiries
#
# 1. Plot the histograms for each of the four quantitative variables
#
#
# 2. Plot the histograms for each of the quantitative variables
#
#
# 3. Plot the boxplots for each of the quantitative variables
#
#
# 4. Plot the boxplots of the petal width grouped by type of flower
#
#
# 5. Plot the boxplots of the setal length grouped by type of flower
#
#
# 6. Provide a description (explaination from your observations) of each of the quantitative variables

# %% [markdown]
# In the following lines are histograms for each of the quantitative variables

# %%
dfhist = sns.distplot(df["SepalLength"], kde = False)
dfhist.set_ylabel("Frequency")
dfhist.set_xlabel("Sepal length")
dfhist.set_title("Distribution of the Sepal length")

plt.show()
# Out:
# C:\Users\luisa\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
dfhist = sns.distplot(df["SepalWidth"], kde = False)
dfhist.set_ylabel("Frequency")
dfhist.set_xlabel("Sepal width")
dfhist.set_title("Distribution of the Sepal width")

plt.show()

# %%
dfhist = sns.distplot(df["PetalLength"], kde = False)
dfhist.set_ylabel("Frequency")
dfhist.set_xlabel("Petal length")
dfhist.set_title("Distribution of the Petal length")

plt.show()

# %%
dfhist = sns.distplot(df["PetalWidth"], kde = False)
dfhist.set_ylabel("Frequency")
dfhist.set_xlabel("Petal width")
dfhist.set_title("Distribution of the Petal width")

plt.show()

# %% [markdown]
# Now we plot in a histogram the characteristics of the petal together

# %%
dfhist = sns.distplot(df["PetalLength"], kde = False)
dfhist = sns.distplot(df["PetalWidth"], kde = False)
dfhist.set_ylabel("Frequency")
dfhist.set_title("Histogram of both Petal length and width")
plt.show()

# %% [markdown]
# Now we plot in a histogram the characteristics of the sepal together

# %%
dfhist = sns.distplot(df["SepalLength"], kde = False)
dfhist = sns.distplot(df["SepalWidth"], kde = False)
dfhist.set_ylabel("Frequency")
dfhist.set_title("Histogram of both Sepal length and width")
plt.show()

# %% [markdown]
# In the following lines are boxplots for each of the quantitative variables

# %%
sns.boxplot(df["SepalLength"]).set_title("Box plot of the Sepal length")
plt.show()
# Out:
# C:\Users\luisa\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(df["SepalWidth"]).set_title("Box plot of the Sepal width")
plt.show()
# Out:
# C:\Users\luisa\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(df["PetalLength"]).set_title("Box plot of the Petal length")
plt.show()
# Out:
# C:\Users\luisa\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(df["PetalWidth"]).set_title("Box plot of the Petal width")
plt.show()
# Out:
# C:\Users\luisa\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Here we plot a boxplot of the petal width grouped by type of flower

# %%
sns.boxplot(x = df["PetalWidth"], y = df["Class"])
plt.show()

# %% [markdown]
# Here we plot a boxplot of the petal length grouped by type of flower

# %%
sns.boxplot(x = df["PetalLength"], y = df["Class"])
plt.show()

# %% [markdown]
# With this plots we can see different characteristics of the flowers in the dataset for example the sepal width mean is around 3, we can see this in the histogram, the 3 has the biggest frequency, and also in the boxplot we have the same result. For all the variables is easier to know the mean by checking the boxplot, but the histogram let's you see all the values that have a bigger frequency.
#
# I believe that the most interesting plot are the boxplots by type of flower, because you can easily see the differences between each type, so you can say that the iris-setos is the smallest flower ant the iris-virginica is the longest flower.
