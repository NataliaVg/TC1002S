# %% [markdown]
# # Visualizing Data in Python
#
# A01639224 | Fausto Alejandro Palma Cervantes
#
# When working with a new dataset, one of the most useful things to do is to begin to visualize the data. By using **tables**, **histograms**, **boxplots**, **scatter plots** and other visual tools, we can get a better idea of what the data may be trying to tell us, and we can gain insights into the data that we may have not discovered otherwise.
#
# In this notebook will use the [Seaborn](https://seaborn.pydata.org/) data processing library, which is a higher-level interface to **Matplotlib** that can be used to simplify many visualization tasks
#
# The **Seaborn** provides visualisations tools that will allow to explore data from a graphical perspective.
#
#
# ## Acknowledgments
#
# - Data from https://www.coursera.org/ from the course "Understanding and Visualizing Data with Python" by University of Michigan

# %% [markdown]
# # Importing libraries

# %%
# Import the packages that we will be using
import pandas as pd                 # For data handling
import seaborn as sns               # For advanced plotting
import matplotlib.pyplot as plt     # For showing plots

# %% [markdown]
# # Importing data

# %%
# url string that hosts our .csv file
url = "datasets/iris/iris.csv"

# Read the .csv file and store it as a pandas Data Frame
df = pd.read_csv(url, names=['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Class'])

# %% [markdown]
# # Exploring the content of the data set
#
# Get a general 'feel' of the data

# %%
df
# df.shape
# df.head()
# df.columns
# df.describe()
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth           Class
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Frequency tables
#
# The `value_counts()` method can be used to determine the number of times that each distinct value of a variable occurs in a data set.  In statistical terms, this is the "frequency distribution" of the variable. The `value_counts()` method produces a table with two columns.  The first column contains all distinct observed values for the variable.  The second column contains the number of times each of these values occurs.  Note that the table returned by `value_counts()` is actually a **Pandas** data frame, so can be further processed using any Pandas methods for working with data frames.

# %%
# Number of times that each distinct value of a variable occurs in a data set
df.SepalLength.value_counts()
# Out:
# 5.0    10
# 6.3     9
# 5.1     9
# 5.7     8
# 6.7     8
# 5.8     7
# 5.5     7
# 6.4     7
# 4.9     6
# 6.0     6
# 5.4     6
# 5.6     6
# 6.1     6
# 6.5     5
# 4.8     5
# 6.2     4
# 5.2     4
# 7.7     4
# 6.9     4
# 4.6     4
# 7.2     3
# 5.9     3
# 4.4     3
# 6.8     3
# 6.6     2
# 4.7     2
# 7.1     1
# 7.4     1
# 7.6     1
# 7.9     1
# 4.5     1
# 7.0     1
# 5.3     1
# 7.3     1
# 4.3     1
# Name: SepalLength, dtype: int64

# %%
# Proportion of each distinct value of a variable occurs in a data set
x = df.SepalLength.value_counts()
x / x.sum()
# Out:
# 5.0    0.066667
# 6.3    0.060000
# 5.1    0.060000
# 5.7    0.053333
# 6.7    0.053333
# 5.8    0.046667
# 5.5    0.046667
# 6.4    0.046667
# 4.9    0.040000
# 6.0    0.040000
# 5.4    0.040000
# 5.6    0.040000
# 6.1    0.040000
# 6.5    0.033333
# 4.8    0.033333
# 6.2    0.026667
# 5.2    0.026667
# 7.7    0.026667
# 6.9    0.026667
# 4.6    0.026667
# 7.2    0.020000
# 5.9    0.020000
# 4.4    0.020000
# 6.8    0.020000
# 6.6    0.013333
# 4.7    0.013333
# 7.1    0.006667
# 7.4    0.006667
# 7.6    0.006667
# 7.9    0.006667
# 4.5    0.006667
# 7.0    0.006667
# 5.3    0.006667
# 7.3    0.006667
# 4.3    0.006667
# Name: SepalLength, dtype: float64

# %% [markdown]
# Note that the `value_counts()` method excludes missing values. We confirm this below by adding up observations to your data frame with some missing values and then computing `value_counts()` and comparing this to the total number of rows in the data set, which is 150. This tells us that there are 150 - 150 = 0 missing values for this variable (other variables may have different numbers of missing values).

# %%
# Total number of observations in tips
print(df.shape)

# Total number of null observations in tips
#print(df.isnull(df.Age).sum())

# Total number of counts (excluding missing values) in tips
print(df.SepalLength.value_counts().sum())
# Out:
# (150, 5)
# 150

# %% [markdown]
# # Histogram
#
# It is often good to get a feel for the shape of the distribution of the data.

# %%
# Plot Sepal Length of each Iris plants
dfhist = sns.distplot(df["SepalLength"], kde = False)
dfhist.set_ylabel("Number of Plants")
dfhist.set_title("Sepal Length in Iris Plants")

plt.show()
# Out:
# /Users/faustopalma/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Plot distribution of Sepal Length in Iris plants
dfhist = sns.distplot(df["SepalLength"], kde = True)
dfhist.set_ylabel("Number of Plants")
dfhist.set_xlabel("Sepal Length (mm)")
dfhist.set_title("Sepal Length in Iris Plants")

plt.show()

# %%
# Plot histogram of both the Sepal Length and the Width
sns.distplot(df["SepalLength"], kde = False)
dfhist = sns.distplot(df["SepalWidth"], kde = False)
dfhist.set_ylabel("Number of Plants")
dfhist.set_title("Sepal Length and Width in Iris Plants")

dfhist.set_xlabel("Size (cm)")

plt.show()
# Out:
# /Users/faustopalma/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Histograms plotted by groups
#
# While looking at a single variable is interesting, it is often useful to see how a variable changes in response to another. Thus, we can create a histograms of one quantitative variable grouped by another categorical variables.

# %%
# Create histograms of the "SepalLength" grouped by "Class"
g = sns.FacetGrid(df, row = "Class")
g = g.map(plt.hist, "SepalLength")

plt.show()

# %% [markdown]
# # Boxplots
#
# Boxplots do not show the shape of the distribution, but they can give us a better idea about the center and spread of the distribution as well as any potential outliers that may exist. Boxplots and Histograms often complement each other and help an analyst get more information about the data

# %%
# Create the boxplot of the Sepal Lengths
sns.boxplot(df["SepalLength"]).set_title("Box Plot of the Sepal Lengths")
plt.show()
# Out:
# /Users/faustopalma/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Create the boxplot of the Sepal Widths
sns.boxplot(df["SepalWidth"]).set_title("Box Plot of the Sepal Widths")
plt.show()
# Out:
# /Users/faustopalma/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Create the boxplots of the "SepalLength" and of the "SepalWidth" sizes
sns.boxplot(df["SepalLength"])
sns.boxplot(df["SepalWidth"]).set_title("Box Plot of the Sepal Lengths and Widths")
plt.show()

# NOTE: This is not convenient
# Out:
# /Users/faustopalma/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/faustopalma/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Create the boxplots of the "SepalLength" and of the "SepalWidth" sizes

SepalLengthAndWidth = df.loc[:, ["SepalLength", "SepalWidth"]]

x2bp = sns.boxplot(data=SepalLengthAndWidth, orient="h")
x2bp.set_xlabel("Size (cm)")
x2bp.set_title("Box Plot of the Sepal Lengths and Widths")

plt.show()

# %% [markdown]
# # Boxplots plotted by groups
#
# While looking at a single variable is interesting, it is often useful to see how a variable changes in response to another. Thus, we can create a side-by-side boxplots of one quantitative variable grouped by another categorical variables.

# %%
# Create side-by-side boxplots of the "SepalLength" grouped by "Class"
sns.boxplot(x = df["SepalLength"], y = df["Class"])
plt.show()

# %% [markdown]
# # Histograms and boxplots plotted by groups
#
# We cal also create both boxplots and histograms of one quantitative variable grouped by another categorical variables

# %%
# Create a boxplot and histogram of the "SepalLengths" grouped by "Class"
sns.boxplot(x = df["SepalLength"], y = df["Class"])

g = sns.FacetGrid(df, row = "Class")
g = g.map(plt.hist, "SepalLength")

plt.show()

# %% [markdown]
# # Final remarks
#
# - Visualizing your data using **tables**, **histograms**, **boxplots**, **scatter plots** and other tools is essential to carry put analysis and extract conclusions
#
# - There are several ways to do the same thing
#
# - The **Seaborn** package provides visualisations tools that allow to explore data from a graphical perspective

# %% [markdown]
# # Activity: work with the Iris dataset
#
# Repeat this tutorial with the iris data set and respond to the following inquiries

# %% [markdown]
# 1. Plot the histograms for each of the four quantitative variables

# %%
# Sepal Length
dfhist = sns.distplot(df["SepalLength"], kde = False)
dfhist.set_ylabel("Number of Plants")
dfhist.set_xlabel("Size (cm)")
dfhist.set_title("Sepal Length in Iris Plants")
plt.show()

# Sepal Width
dfhist = sns.distplot(df["SepalWidth"], kde = False)
dfhist.set_ylabel("Number of Plants")
dfhist.set_xlabel("Size (cm)")
dfhist.set_title("Sepal Width in Iris Plants")
plt.show()

# Petal Length
dfhist = sns.distplot(df["PetalLength"], kde = False)
dfhist.set_ylabel("Number of Plants")
dfhist.set_xlabel("Size (cm)")
dfhist.set_title("Petal Length in Iris Plants")
plt.show()

# Petal Width
dfhist = sns.distplot(df["PetalWidth"], kde = False)
dfhist.set_ylabel("Number of Plants")
dfhist.set_xlabel("Size (cm)")
dfhist.set_title("Petal Width in Iris Plants")
plt.show()
# Out:
# /Users/faustopalma/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# 2. Plot the histograms for each of the quantitative variables

# %%
# Histogram of all quantitative variables
sns.distplot(df["SepalLength"], kde = False)
dfhist = sns.distplot(df["SepalWidth"], kde = False)
dfhist = sns.distplot(df["PetalLength"], kde = False)
dfhist = sns.distplot(df["PetalWidth"], kde = False)
dfhist.set_ylabel("Number of Plants")
dfhist.set_xlabel("Size (cm)")
dfhist.set_title("Sepal Dimensions in Iris Plants")
plt.show()

# %% [markdown]
# 3. Plot the boxplots for each of the quantitative variables

# %%
# Sepal Length
sns.boxplot(df["SepalLength"]).set_title("Box Plot of the Sepal Lengths")
plt.show()

# Sepal Width
sns.boxplot(df["SepalWidth"]).set_title("Box Plot of the Sepal Widths")
plt.show()

# Petal Length
sns.boxplot(df["PetalLength"]).set_title("Box Plot of the Petal Lengths")
plt.show()

# Petal Width
sns.boxplot(df["SepalLength"]).set_title("Box Plot of the Petal Widths")
plt.show()
# Out:
# /Users/faustopalma/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/faustopalma/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# 4. Plot the boxplots of the petal width grouped by type of flower

# %%
# Boxplot of petal width grouped by type of flower
bp = sns.boxplot(x = df["PetalWidth"], y = df["Class"])
bp.set_xlabel("Size (cm)")
bp.set_ylabel("Species")
bp.set_title("Box Plot of Petal Widths Grouped by Type of Flower")

plt.show()

# %% [markdown]
# 5. Plot the boxplots of the sepal length grouped by type of flower

# %%
# Boxplot of sepal length grouped by type of flower
bp = sns.boxplot(x = df["SepalLength"], y = df["Class"])
bp.set_xlabel("Size (cm)")
bp.set_ylabel("Species")
bp.set_title("Box Plot of Sepal Lengths Grouped by Type of Flower")

plt.show()

# %% [markdown]
# 6. Provide a description (explaination from your observations) of each of the quantitative variables
#
#     There are four quantitative variables:
#         - The SepalLength variable is a quantitative variable and a float data type that stores the length measurement size of the Iris Sepal leaves.
#         - The SepalWidth variable is a quantitative variable and a float data type that stores the width measurement size of the Iris Sepal leaves.
#         - The PetalLength variable is a quantitative variable and a float data type that stores the length measurement size of the Iris Petal leaves.
#         - The PetalWidth variable is a quantitative variable and a float data type that stores the width measurement size of the Iris Petal leaves.
